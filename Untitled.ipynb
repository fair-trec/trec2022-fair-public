# %%
import pandas as pd
import xarray as xr
import numpy as np

# %%
from wptrec.dimension import *

# %%
from MetricInputs import *
# Out:
# D:\Research\trec\trec2022-analysis\MetricInputs.py:49: UserWarning: No DATA_MODE specified, assuming ‘train’
#   warnings.warn('No DATA_MODE specified, assuming ‘train’')

# %%
dimensions
# Out:
# [<dimension "sub-geo": 21 levels>,
#  <dimension "src-geo": 21 levels>,
#  <dimension "gender": 4 levels>,
#  <dimension "occ": 33 levels>,
#  <dimension "alpha": 4 levels>,
#  <dimension "age": 4 levels>,
#  <dimension "pop": 4 levels>,
#  <dimension "langs": 3 levels>]

# %%
pages = dimensions[0].page_align_xr.coords['page'][:100].values
pages
# Out:
# array([ 12,  25,  39, 290, 303, 305, 307, 308, 309, 316, 324, 330, 332,
#        334, 336, 339, 340, 344, 358, 359, 569, 572, 573, 579, 580, 586,
#        590, 593, 594, 595, 597, 599, 600, 612, 615, 620, 621, 624, 627,
#        628, 630, 632, 633, 634, 639, 640, 642, 643, 649, 651, 653, 655,
#        656, 657, 659, 661, 662, 663, 664, 665, 666, 670, 673, 674, 675,
#        676, 677, 678, 679, 680, 681, 682, 683, 689, 690, 691, 694, 698,
#        700, 701, 704, 705, 706, 708, 709, 710, 711, 713, 717, 728, 734,
#        736, 737, 738, 740, 742, 746, 748, 751, 752], dtype=int64)

# %%
aa = agg_alignments([d.page_align_xr.loc[pages] for d in dimensions], 'mean')

# %%
aa
# Out:
# <xarray.DataArray (sub-geo: 21, src-geo: 21, gender: 4, occ: 33, alpha: 4,
#                    age: 4, pop: 4, langs: 3)>
# array([[[[[[[[0.00000000e+00, 2.39460472e-01, 0.00000000e+00],
#              [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#              [0.00000000e+00, 2.64000000e-02, 0.00000000e+00],
#              [0.00000000e+00, 3.50000000e-02, 1.00000000e-02]],
#
#             [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#              [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#              [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#              [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#             [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#              [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#              [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#              [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#             [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
# ...

# %%
aa.sum()
# Out:
# <xarray.DataArray ()>
# array(1.)
